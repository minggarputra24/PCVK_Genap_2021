# %% [markdown]
# <a href="https://colab.research.google.com/github/minggarputra24/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nomor 1
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Nomor 2
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
from skimage import transform
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening, area_closing, area_opening)
from skimage.color import rgb2gray

# %%
#Nomor 3
img = cv.imread('/content/drive/MyDrive/PCVK/Images/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde60671cd0>,
#  <matplotlib.image.AxesImage at 0x7fde6065b6d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#Nomor 4
img1= cv.imread('/content/drive/MyDrive/PCVK/Images/j.png', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde600fd510>,
#  <matplotlib.image.AxesImage at 0x7fde600d2e10>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#Nomor 5
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde600e1390>,
#  <matplotlib.image.AxesImage at 0x7fde5ffb7150>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#Nomor 6
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5ffb7690>,
#  <matplotlib.image.AxesImage at 0x7fde5ff0e410>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#Nomor 7
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fe8ed50>,
#  <matplotlib.image.AxesImage at 0x7fde5fe5e650>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
#Nomor 8
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fe5eb90>,
#  <matplotlib.image.AxesImage at 0x7fde5fd30890>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
#Nomor 9 
#SED = Cross 3
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fd30dd0>,
#  <matplotlib.image.AxesImage at 0x7fde5fc82c10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
#Nomor 9
#SED = Cross 5
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fc8f190>,
#  <matplotlib.image.AxesImage at 0x7fde5fbceed0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %%
#Nomor 10
#SED = Circular 3
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fbde450>,
#  <matplotlib.image.AxesImage at 0x7fde5fb21a10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi Circular 3x3'))

# %%
#Nomor 10
#SED = Circle 5
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi Circular 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fb21f50>,
#  <matplotlib.image.AxesImage at 0x7fde5f9f1590>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi Circular 5x5'))

# %%
#Nomor 11
#SE = Rectangle 3x5
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Erosi Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5f9f1ad0>,
#  <matplotlib.image.AxesImage at 0x7fde5f93bfd0>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi Rectangle 3x5'))

# %%
#Nomor 11
#SE = Rectangle 5x7
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Erosi Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fff8e10>,
#  <matplotlib.image.AxesImage at 0x7fde5fe33350>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi Rectangle 5x7'))

# %%
#NOMOR 12
#SE = Line Vertikal 3
kernel = np.ones((3,1),np.uint8) 
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel) 
print("SE = Line Vertikal 3") 
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal') 
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi Line Vertikal 3')
# Out:
# SE = Line Vertikal 3
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5fe33c50>,
#  <matplotlib.image.AxesImage at 0x7fde5f78ba10>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi Line Vertikal 3'))

# %%
#NOMOR 12
#SE = Line Vertikal 5
kernel = np.ones((5,1),np.uint8) 
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal') 
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi Line Vertikal 5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fde5f78bf50>,
#  <matplotlib.image.AxesImage at 0x7fde5f6d9e50>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi Line Vertikal 5'))
